# %%
import pandas as pd
import sqlite3
from flask import jsonify

# %%
DATABASE = 'catering_sqlite.db'

conn = sqlite3.connect(DATABASE)

cursor = conn.cursor()

# %%
cursor.execute("""CREATE TABLE IF NOT EXISTS equipment (
  `name` VARCHAR(100) NOT NULL,
  `cost_per_item` FLOAT NOT NULL,
  `category` VARCHAR(45) NOT NULL,
  PRIMARY KEY (`name`))""")

# %%
cursor.execute("""CREATE TABLE IF NOT EXISTS bar_items (
  `name` VARCHAR(50) NOT NULL,
  `cost_per_item` FLOAT NOT NULL,
  `category` VARCHAR(50) NOT NULL,
  `serving_container` VARCHAR(100) NOT NULL,
  PRIMARY KEY (`name`),
  CONSTRAINT `fk_bar_item_container`
    FOREIGN KEY (`serving_container`)
    REFERENCES `equipment` (`name`))""")

# %%
cursor.execute("""CREATE TABLE IF NOT EXISTS labor_cost (
  `role` VARCHAR(45) NOT NULL,
  `cost_per_hour` FLOAT NOT NULL,
  PRIMARY KEY (`role`))""")

# %%
cursor.execute("""CREATE TABLE IF NOT EXISTS menu_items (
  `name` VARCHAR(100) NOT NULL,
  `course` VARCHAR(45) NOT NULL,
  `prep_time` INT NOT NULL,
  `cook_time` INT NOT NULL,
  `serving_container` VARCHAR(100) NULL DEFAULT NULL,
  `serving_utensil` VARCHAR(100) NULL DEFAULT NULL,
  `oven` TINYINT NOT NULL,
  `fridge` TINYINT NOT NULL,
  `cost_per_item` FLOAT NOT NULL,
  PRIMARY KEY (`name`),
  CONSTRAINT `fk_menu_items_container`
    FOREIGN KEY (`serving_container`)
    REFERENCES `equipment` (`name`),
  CONSTRAINT `fk_menu_items_utensil`
    FOREIGN KEY (`serving_utensil`)
    REFERENCES `equipment` (`name`))""")

# %%
cursor.execute("""CREATE TABLE IF NOT EXISTS `menu_item_ingredients` (
  `menu_item` VARCHAR(100) NOT NULL,
  `menu_item_ingredient` VARCHAR(250) NOT NULL,
  `quantity` FLOAT NOT NULL,
  `production_amount` INT NOT NULL,
  PRIMARY KEY (`menu_item`, `menu_item_ingredient`),
  CONSTRAINT `fk_menu_item_ingredients_menu_item`
    FOREIGN KEY (`menu_item`)
    REFERENCES `menu_items` (`name`)
    ON DELETE CASCADE
    ON UPDATE CASCADE)""")

# %%
cursor.execute("""INSERT INTO equipment(name, cost_per_item, category) VALUES ('Wood Chiavari Chair', 2.97, 'Chairs'), ('Ghost Chair With Arms', 4.93, 'Chairs'), ('Industrial Metal Chair with Arms', 4.99, 'Chairs'), ('Farmhouse Cross Back Chair', 3.4, 'Chairs'), ('King Louis Chair', 7.47, 'Chairs'), ('Titan Plastic Folding Chair', 0.9, 'Chairs'), ('Titan Aluminum Plastic Folding Chair', 1.35, 'Chairs'), ('Wood Folding Chair', 1.77, 'Chairs'), ('French Bistro Folding Chair', 2.0, 'Chairs'), ("60'' Round Wood Folding Table (Seats 5-6)", 8.67, 'Tables'), ("72'' Round Wood Folding Table (Seats 8-10)", 11.47, 'Tables'), ("60'' Round Plastic Folding Table (Seats 5-6)", 9.22, 'Tables'), ("72'' Round Plastic Folding Table (Seats 8-10)", 13.62, 'Tables'), ("Plastic Folding Table - 8'x30'' banquet (Seats 8-10)", 7.5, 'Tables'), ("Plastic Folding Table - 6' x 30'' Banquet (Seats 6-8)", 4.97, 'Tables'), ("Wood Folding Table - 8'x30'' banquet (Seats 8-10)", 10.56, 'Tables'), ("Wood Folding Table - 6' x 30'' Banquet (Seats 6-8)", 6.74, 'Tables'), ("Farmhouse Folding Farm Table - 8'x40'' - Rustic - H-Legs (Seats 8-12)", 27.02, 'Tables'), ("Industrial Metal Cocktail Table 30'' Square", 15.7, 'Cocktail Tables'), ("Cocktail table - 24'' Wood Round", 12.85, 'Cocktail Tables'), ("Cocktail table - 30'' Wood Round", 13.25, 'Cocktail Tables'), ("Cocktail table - 36'' Wood Round", 13.85, 'Cocktail Tables'), ("Cocktail table - 30'' Wood Square", 12.95, 'Cocktail Tables'), ("Cocktail table - 36'' Wood Square", 13.15, 'Cocktail Tables'), ('Tablecloths (Black, White, Ivory, Navy, Grey)', 10.0, 'Table Linens'), ('Table Runners (Black, White, Ivory, Navy, Grey)', 8.0, 'Table Linens'), ('Sun Umbrella', 20.0, 'Extras'), ("Small Stage (5' x 10')", 500.0, 'Extras'), ("Large Stage (10' x 15')", 1000.0, 'Extras'), ("Small Dance Floor (12' Square)", 250.0, 'Extras'), ("Large Dance Floor (20' Square)", 500.0, 'Extras'), ('Podium', 75.0, 'Extras'), ("Plastic Dinner Plate-10''", 0.3, 'Tableware'), ("Plastic Salad/Dessert Plate- 6''", 0.15, 'Tableware'), ('Porcelain Dinner Plate-10"', 1.5, 'Tableware'), ('Porcelain Salad/Dessert Plate 6"', 1.0, 'Tableware'), ('Plastic Fork', 0.1, 'Tableware'), ('Plastic Knive', 0.1, 'Tableware'), ('Dinner Fork-Stainless (10pk)', 0.5, 'Tableware'), ('Dinner Knife-Stainless (10pk)', 0.5, 'Tableware'), ('Plastic Cups 12oz', 0.2, 'Tableware'), ('Plastic Wine Cups 9oz', 0.15, 'Tableware'), ('Beer Pilsner Glass', 1.5, 'Tableware'), ('Champagne Flute', 2.5, 'Tableware'), ('Red Wine-12oz.', 1.5, 'Tableware'), ('Water Goblets', 1.5, 'Tableware'), ('White Wine-11oz', 1.5, 'Tableware'), ('Old Fashioned Glass', 2.5, 'Tableware'), ('Oven', 400.0, 'Kitchen'), ('Refrigerator', 300.0, 'Kitchen'), ("12 '' Oval Ceramic Platter", 2.42, 'Serving'), ('18" x 5" Rectangular Ceramic Serving Platter', 4.85, 'Serving'), ('Rectangular Chafing Dish', 23.28, 'Serving'), ('Round Chafing Dish', 17.2, 'Serving'), ('Serving Spoon', 1.35, 'Serving'), ('Serving Fork', 1.35, 'Serving'), ('Spatula', 1.5, 'Serving'), ('Appetizer Tongs', 1.5, 'Serving'), ('Serving Tongs', 1.82, 'Serving'), ('Salad Serving Bowl', 3.9, 'Serving')""")

# %%
cursor.execute("""INSERT INTO menu_items(name, course, prep_time, cook_time, serving_container,	serving_utensil, oven, 
fridge, cost_per_item) VALUES ('Baked Chicken Wings with Thai Peanut Sauce', 'Appetizers', 40, 50, "12 '' Oval Ceramic Platter", 'Appetizer Tongs', 1, 0, 2.49), ('Homemade Chorizo Meatballs in Cilantro Masa Cups', 'Appetizers', 10, 28, "12 '' Oval Ceramic Platter", 'Appetizer Tongs', 1, 0, 0.99), ('Bruschetta Caprese', 'Appetizers', 10, 10, "12 '' Oval Ceramic Platter", 'Appetizer Tongs', 0, 1, 1.49), ('Beet-Pickled Quail Eggs', 'Appetizers', 20, 10, "12 '' Oval Ceramic Platter", 'Appetizer Tongs', 0, 1, 1.99), ('Fried Green Tomato Tacos', 'Appetizers', 20, 20, "12 '' Oval Ceramic Platter", 'Appetizer Tongs', 0, 0, 2.49), ('Chinese Sticky Rice Prawn Parcels', 'Appetizers', 20, 15, "12 '' Oval Ceramic Platter", 'Appetizer Tongs', 1, 0, 2.49), ('Ham Jalapeno Green Onion Quesadilla', 'Appetizers', 5, 10, "12 '' Oval Ceramic Platter", 'Appetizer Tongs', 1, 0, 1.99), ('Rosemary Parmesan Focaccia', 'Breads', 10, 10, '18" x 5" Rectangular Ceramic Serving Platter', 'Serving Tongs', 1, 0, 2.49), ('Buttermilk Cornbread', 'Breads', 10, 20, '18" x 5" Rectangular Ceramic Serving Platter', 'Serving Tongs', 1, 0, 2.99), ('Cheese Garlic Biscuits', 'Breads', 10, 20, '18" x 5" Rectangular Ceramic Serving Platter', 'Serving Tongs', 1, 0, 2.49), ('Basil-Buttered French Bread', 'Breads', 10, 10, '18" x 5" Rectangular Ceramic Serving Platter', 'Serving Tongs', 1, 0, 3.49), ('Tiramisu (Serves 10)', 'Desserts', 15, 3, "12 '' Oval Ceramic Platter", 'Spatula', 0, 1, 19.99), ('Triple Chocolate Cookies', 'Desserts', 15, 15, "12 '' Oval Ceramic Platter", 'Appetizer Tongs', 0, 0, 2.49), ('Sweet Cherry Pie (Serves 8)', 'Desserts', 15, 30, 'Porcelain Dinner Plate-10"', 'Spatula', 1, 0, 14.99), ('Toasted-Pecan Pie (Serves 8)', 'Desserts', 15, 30, 'Porcelain Dinner Plate-10"', 'Spatula', 1, 0, 14.99), ('Almond Biscotti', 'Desserts', 45, 15, "12 '' Oval Ceramic Platter", 'Appetizer Tongs', 0, 0, 1.99), ('French Meringues', 'Desserts', 5, 10, "12 '' Oval Ceramic Platter", 'Appetizer Tongs', 0, 0, 2.99), ('Soft Sugar Cookies', 'Desserts', 30, 20, "12 '' Oval Ceramic Platter", 'Appetizer Tongs', 0, 0, 2.49), ('Fresh Persimmon Cake (Serves 10)', 'Desserts', 10, 15, "12 '' Oval Ceramic Platter", 'Spatula', 1, 0, 24.99), ('Honey-Mustard Pork Tenderloin with Kale', 'Main Dishes', 30, 45, 'Rectangular Chafing Dish', 'Serving Tongs', 1, 0, 27.99), ('Baked Chicken Bean and Cheese Empanadas', 'Main Dishes', 30, 30, 'Rectangular Chafing Dish', 'Serving Tongs', 1, 0, 19.99), ('Ricotta and Spinach Stuffed Manicotti', 'Main Dishes', 30, 45, 'Rectangular Chafing Dish', 'Serving Spoon', 1, 0, 22.99), ('Ricotta Fettuccine Alfredo with Broccoli', 'Main Dishes', 30, 20, 'Rectangular Chafing Dish', 'Serving Tongs', 1, 1, 21.99), ('Italian Pot Roast with Artichokes and Potatoes', 'Main Dishes', 30, 60, 'Rectangular Chafing Dish', 'Serving Tongs', 1, 0, 29.99), ('Veal Ravioli with Walnut Sauce', 'Main Dishes', 30, 20, 'Rectangular Chafing Dish', 'Serving Tongs', 1, 0, 32.99), ('Teriyaki Salmon with Cucumber Salad', 'Main Dishes', 30, 20, 'Rectangular Chafing Dish', 'Spatula', 1, 1, 34.99), ('Chicken Tikka Masala', 'Main Dishes', 30, 30, 'Rectangular Chafing Dish', 'Serving Spoon', 1, 0, 23.99), ('Quiche Lorraine', 'Main Dishes', 30, 40, 'Rectangular Chafing Dish', 'Spatula', 1, 0, 21.99), ('Indian Almond Chicken with Peas', 'Main Dishes', 30, 40, 'Rectangular Chafing Dish', 'Serving Spoon', 1, 0, 26.99), ('Mexican Baked Spaghetti Squash', 'Main Dishes', 30, 35, 'Rectangular Chafing Dish', 'Serving Spoon', 1, 0, 21.99), ('Risotto With Lemon And Sun Dried Tomatoes', 'Main Dishes', 15, 40, 'Rectangular Chafing Dish', 'Serving Tongs', 1, 0, 22.99), ('Red Cabbage, Cranberry, and Apple Slaw', 'Salads', 15, 5, 'Salad Serving Bowl', 'Serving Tongs', 0, 1, 7.99), ('Quinoa Salad with Grilled Scallions, Favas and Dates', 'Salads', 15, 5, 'Salad Serving Bowl', 'Serving Spoon', 0, 1, 6.99), ('Mixed Greens with Smoked Gouda', 'Salads', 15, 5, 'Salad Serving Bowl', 'Serving Tongs', 0, 1, 7.99), ('Crunchy Romaine Toss', 'Salads', 15, 5, 'Salad Serving Bowl', 'Serving Tongs', 0, 1, 6.99), ('Panzanella', 'Salads', 15, 5, 'Salad Serving Bowl', 'Serving Spoon', 0, 1, 5.99), ('Mediterranean Chopped Salad with Tomatoes, Peppers, Feta, and Basil', 'Salads', 15, 5, 'Salad Serving Bowl', 'Serving Tongs', 0, 1, 8.99), ('Cucumber Salad', 'Salads', 15, 5, 'Salad Serving Bowl', 'Serving Spoon', 0, 1, 6.99), ('Green Beans with Roasted Tomatoes and Cumin', 'Side Dishes', 10, 20, 'Round Chafing Dish', 'Serving Tongs', 1, 0, 4.99), ('Elote, or Mexican Grilled Corn', 'Side Dishes', 5, 30, 'Round Chafing Dish', 'Serving Tongs', 1, 0, 4.99), ('Glazed Root Vegetables', 'Side Dishes', 10, 30, 'Round Chafing Dish', 'Serving Spoon', 1, 0, 3.99), ('Roasted New Potatoes', 'Side Dishes', 5, 40, 'Round Chafing Dish', 'Serving Spoon', 1, 0, 3.99), ('Best Ever Boston Baked Beans', 'Side Dishes', 10, 30, 'Round Chafing Dish', 'Serving Spoon', 1, 0, 4.99), ('Cilantro Serrano Mexican Rice', 'Side Dishes', 10, 20, 'Round Chafing Dish', 'Serving Spoon', 1, 0, 3.99), ('Grilled Fresh Artichokes', 'Side Dishes', 20, 45, 'Round Chafing Dish', 'Serving Tongs', 1, 0, 7.99), ('Pineapple Fried Rice', 'Side Dishes', 10, 20, 'Round Chafing Dish', 'Serving Spoon', 1, 0, 4.99)
""")

# %%
cursor.execute("""INSERT INTO bar_items (name, cost_per_item, category, serving_container) VALUES ('Coke 2L Bottle', 5.48, 'Soft Drinks', 'Plastic Cups 12oz'), ('Diet Coke 2L Bottle', 5.48, 'Soft Drinks', 'Plastic Cups 12oz'), ('Sprite 2L Bottle', 5.48, 'Soft Drinks', 'Plastic Cups 12oz'), ('Dr. Pepper 2L Bottle', 5.28, 'Soft Drinks', 'Plastic Cups 12oz'), ('Fanta 2L Bottle', 3.76, 'Soft Drinks', 'Plastic Cups 12oz'), ('Modelo 12 Pack Bottles', 32.84, 'Beer', 'Beer Pilsner Glass'), ('Budweiser 12 Pack Bottles', 26.24, 'Beer', 'Beer Pilsner Glass'), ('Bud Light 12 Pack Bottles', 26.24, 'Beer', 'Beer Pilsner Glass'), ('Heineken 12 Pack Bottles', 32.88, 'Beer', 'Beer Pilsner Glass'), ('Lagunitas 12 Pack Bottles', 33.68, 'Beer', 'Beer Pilsner Glass'), ('Sierra Nevada 12 Pack Bottles', 39.46, 'Beer', 'Beer Pilsner Glass'), ('Barefoot Chardonnay 750 mL Bottle', 11.92, 'Wine', 'White Wine-11oz'), ('Apothic Red Blend 750 mL Bottle', 18.24, 'Wine', 'Red Wine-12oz.'), ('La Crema Pinor Noir 750 mL Bottle', 45.96, 'Wine', 'Red Wine-12oz.'), ('Yellow Tail Reisling 750 mL Bottle', 19.74, 'Wine', 'White Wine-11oz'), ('Kirkland Chianti 750 mL Bottle', 17.98, 'Wine', 'Red Wine-12oz.'), ('Cupcake Pinot Grigio 750 mL Bottle', 17.66, 'Wine', 'White Wine-11oz'), ('Bollinger Champagne 750 mL Bottle', 65.8, 'Wine', 'Champagne Flute'), ("Jack Daniel's Whiskey 750 mL Bottle", 35.96, 'Liquor', 'Old Fashioned Glass'), ('Smirnoff Vodka 750 mL Bottle', 39.74, 'Liquor', 'Old Fashioned Glass'), ('Bacardi Rum 750 mL Bottle', 39.96, 'Liquor', 'Old Fashioned Glass'), ('Patron Tequila 750 mL Bottle', 70.24, 'Liquor', 'Old Fashioned Glass'), ('Tanquerey Gin 750 mL Bottle', 47.68, 'Liquor', 'Old Fashioned Glass')""")

# %%
cursor.execute("INSERT INTO labor_cost (role, cost_per_hour) VALUES ('Manager', 50), ('Server', 25), ('Bartender', 35), ('Event Chef', 40), ('Prep Chef', 30)")

# %%
menu_items_ingredients = pd.read_csv('ingredients_finished.csv').iloc[:]
menu_items_ingredients = menu_items_ingredients.drop_duplicates(subset = ['Menu_Item', 'Ingredient'])
menu_items_ingredients.columns = ['menu_item', 'menu_item_ingredient', 'quantity', 'production_amount']

# %%
menu_items_ingredients.to_sql('menu_item_ingredients', conn, if_exists='append', index=False)
# Out:
# 509

# %%
categories = ['Beer', 'Wine', 'Liquor', 'Soft Drinks']
categorized_bar_items = {cat: [] for cat in categories}

# %%
bar_items = conn.execute('SELECT name, cost_per_item AS price, category FROM bar_items ORDER BY name').fetchall()

# %%
conn.row_factory = sqlite3.Row

# %%
cursor.execute("select sql from sqlite_master where type='table'")
schema = cursor.fetchall()

# %%
list(schema)
# Out:
# [('CREATE TABLE equipment (\n  `name` VARCHAR(100) NOT NULL,\n  `cost_per_item` FLOAT NOT NULL,\n  `category` VARCHAR(45) NOT NULL,\n  PRIMARY KEY (`name`))',),
#  ('CREATE TABLE bar_items (\n  `name` VARCHAR(50) NOT NULL,\n  `cost_per_item` FLOAT NOT NULL,\n  `category` VARCHAR(50) NOT NULL,\n  `serving_container` VARCHAR(100) NOT NULL,\n  PRIMARY KEY (`name`),\n  CONSTRAINT `fk_bar_item_container`\n    FOREIGN KEY (`serving_container`)\n    REFERENCES `equipment` (`name`))',),
#  ('CREATE TABLE labor_cost (\n  `role` VARCHAR(45) NOT NULL,\n  `cost_per_hour` FLOAT NOT NULL,\n  PRIMARY KEY (`role`))',),
#  ('CREATE TABLE menu_items (\n  `name` VARCHAR(100) NOT NULL,\n  `course` VARCHAR(45) NOT NULL,\n  `prep_time` INT NOT NULL,\n  `cook_time` INT NOT NULL,\n  `serving_container` VARCHAR(100) NOT NULL,\n  `serving_utensil` VARCHAR(100) NOT NULL,\n  `oven` TINYINT NOT NULL,\n  `fridge` TINYINT NOT NULL,\n  `cost_per_item` FLOAT NOT NULL,\n  PRIMARY KEY (`name`),\n  CONSTRAINT `fk_menu_items_container`\n    FOREIGN KEY (`serving_container`)\n    REFERENCES `equipment` (`name`),\n  CONSTRAINT `fk_menu_items_utensil`\n    FOREIGN KEY (`serving_utensil`)\n    REFERENCES `equipment` (`name`))',),
#  ('CREATE TABLE `menu_item_ingredients` (\n  `menu_item` VARCHAR(100) NOT NULL,\n  `menu_item_ingredient` VARCHAR(250) NOT NULL,\n  `quantity` FLOAT NOT NULL,\n  `production_amount` INT NOT NULL,\n  PRIMARY KEY (`menu_item`, `menu_item_ingredient`),\n  CONSTRAINT `fk_menu_item_ingredients_menu_item`\n    FOREIGN KEY (`menu_item`)\n    REFERENCES `menu_items` (`name`)\n    ON DELETE CASCADE\n    ON UPDATE CASCADE)',)]

# %%
for table in tables:
    print(table['name'])
# Out:
# equipment
# bar_items
# labor_cost
# menu_items
# menu_item_ingredients

# %%
bar_items = conn.execute("SELECT name FROM bar_items").fetchall()

# %%
[{'name':x['name']} for x in bar_items]
# Out:
# [{'name': 'Apothic Red Blend 750 mL Bottle'},
#  {'name': 'Bacardi Rum 750 mL Bottle'},
#  {'name': 'Barefoot Chardonnay 750 mL Bottle'},
#  {'name': 'Bollinger Champagne 750 mL Bottle'},
#  {'name': 'Bud Light 12 Pack Bottles'},
#  {'name': 'Budweiser 12 Pack Bottles'},
#  {'name': 'Coke 2L Bottle'},
#  {'name': 'Cupcake Pinot Grigio 750 mL Bottle'},
#  {'name': 'Diet Coke 2L Bottle'},
#  {'name': 'Dr. Pepper 2L Bottle'},
#  {'name': 'Fanta 2L Bottle'},
#  {'name': 'Heineken 12 Pack Bottles'},
#  {'name': "Jack Daniel's Whiskey 750 mL Bottle"},
#  {'name': 'Kirkland Chianti 750 mL Bottle'},
#  {'name': 'La Crema Pinor Noir 750 mL Bottle'},
#  {'name': 'Lagunitas 12 Pack Bottles'},
#  {'name': 'Modelo 12 Pack Bottles'},
#  {'name': 'Patron Tequila 750 mL Bottle'},
#  {'name': 'Sierra Nevada 12 Pack Bottles'},
#  {'name': 'Smirnoff Vodka 750 mL Bottle'},
#  {'name': 'Sprite 2L Bottle'},
#  {'name': 'Tanquerey Gin 750 mL Bottle'},
#  {'name': 'Yellow Tail Reisling 750 mL Bottle'}]

# %%
bar_items.fetchall()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 bar_items.fetchall()
#
# AttributeError: 'list' object has no attribute 'fetchall'

# %%
categorized_bar_items = {cat: [] for cat in categories}
for item in bar_items:
    for cat in categories:
        if cat == item['category']:
            categorized_bar_items[cat].append(dict(item))

# %%
count = conn.execute(f"SELECT COUNT(*) FROM bar_items").fetchall

# %%
count[0][count[0].keys()[0]]
# Out:
# 23

# %%
[(x,y) for (x,y) in (categorized_bar_items.keys(), categorized_bar_items.values())]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[235], line 1
# ----> 1 [(x,y) for (x,y) in (categorized_bar_items.keys(), categorized_bar_items.values())]
#
# ValueError: too many values to unpack (expected 2)

# %%
from flask import jsonify

# %%
item_types = ['menu', 'bar', 'equipment']

# %%
mapper = {'menu':'menu_items', 'bar':'bar_items', 'equipment':'equipment'}

# %%
conn.row_factory = sqlite3.Row

# %%
cursor = conn.cursor()
pd.DataFrame(cursor.execute("SELECT * FROM menu_item_ingredients LIMIT 10").fetchall(), columns = [x[0] for x in cursor.description]).columns
# Out:
# Index(['menu_item', 'menu_item_ingredient', 'quantity', 'production_amount'], dtype='object')

# %%
cursor.description
# Out:
# (('name', None, None, None, None, None, None),
#  ('course', None, None, None, None, None, None),
#  ('prep_time', None, None, None, None, None, None),
#  ('cook_time', None, None, None, None, None, None),
#  ('serving_container', None, None, None, None, None, None),
#  ('serving_utensil', None, None, None, None, None, None),
#  ('oven', None, None, None, None, None, None),
#  ('fridge', None, None, None, None, None, None),
#  ('cost_per_item', None, None, None, None, None, None))

# %%
oven, fridge = (False, False)

# %%
my_string = 'hey'

# %%
if True and my_string == 'hey':
    print('True')
# Out:
# True

# %%
my_dict = {'other_details': {'eventDate': '5555-05-05', 'eventStartTime': '05:55', 'eventEndTime': '05:55', 'numGuests': '50', 'eventType': 'wedding', 'eventLocation': '12 Rue Bichat Lyon France', 'venueKitchen': 'no', 'specialRequests': '', 'barService': 'yes', 'equipmentRental': 'yes'}}

# %%
my_dict.get('other_details')
# Out:
# {'eventDate': '5555-05-05',
#  'eventStartTime': '05:55',
#  'eventEndTime': '05:55',
#  'numGuests': '50',
#  'eventType': 'wedding',
#  'eventLocation': '12 Rue Bichat Lyon France',
#  'venueKitchen': 'no',
#  'specialRequests': '',
#  'barService': 'yes',
#  'equipmentRental': 'yes'}

# %%
conn = sqlite3.connect(DATABASE)
cursor = conn.cursor()
conn.row_factory = sqlite3.Row

# %%
item_name = 'Baked Chicken Wings with Thai Peanut Sauce'

# %%
menu_item_details =  conn.execute(f'''SELECT * FROM menu_items WHERE name = "{item_name}"''').fetchone()
ingredient_details = conn.execute(f'''SELECT * FROM menu_items 
                                LEFT JOIN menu_item_ingredients AS mii ON menu_items.name = mii.menu_item 
                                WHERE menu_items.name = "{item_name}"''').fetchall()

# %%
info = conn.execute("SELECT * FROM menu_items AS m LEFT JOIN equipment AS e on m.serving_container = e.name").fetchall()

# %%
pd.DataFrame(info)
# Out:
#                                                    0            1   2   3   \
# 0          Baked Chicken Wings with Thai Peanut Sauce   Appetizers  40  50
# 1    Homemade Chorizo Meatballs in Cilantro Masa Cups   Appetizers  10  28
# 2                                  Bruschetta Caprese   Appetizers  10  10
# 3                             Beet-Pickled Quail Eggs   Appetizers  20  10
# 4                            Fried Green Tomato Tacos   Appetizers  20  20
# 5                   Chinese Sticky Rice Prawn Parcels   Appetizers  20  15
# 6                 Ham Jalapeno Green Onion Quesadilla   Appetizers   5  10
# 7                          Rosemary Parmesan Focaccia       Breads  10  10
# 8                                Buttermilk Cornbread       Breads  10  20
# 9                              Cheese Garlic Biscuits       Breads  10  20
# 10                        Basil-Buttered French Bread       Breads  10  10
# 11                               Tiramisu (Serves 10)     Desserts  15   3
# 12                           Triple Chocolate Cookies     Desserts  15  15
# 13                        Sweet Cherry Pie (Serves 8)     Desserts  15  30
# 14                       Toasted-Pecan Pie (Serves 8)     Desserts  15  30
# 15                                    Almond Biscotti     Desserts  45  15
# 16                                   French Meringues     Desserts   5  10
# 17                                 Soft Sugar Cookies     Desserts  30  20
# 18                   Fresh Persimmon Cake (Serves 10)     Desserts  10  15
# 19            Honey-Mustard Pork Tenderloin with Kale  Main Dishes  30  45
# 20            Baked Chicken Bean and Cheese Empanadas  Main Dishes  30  30
# 21              Ricotta and Spinach Stuffed Manicotti  Main Dishes  30  45
# 22           Ricotta Fettuccine Alfredo with Broccoli  Main Dishes  30  20
# 23     Italian Pot Roast with Artichokes and Potatoes  Main Dishes  30  60
# 24                     Veal Ravioli with Walnut Sauce  Main Dishes  30  20
# 25                Teriyaki Salmon with Cucumber Salad  Main Dishes  30  20
# 26                               Chicken Tikka Masala  Main Dishes  30  30
# 27                                    Quiche Lorraine  Main Dishes  30  40
# 28                    Indian Almond Chicken with Peas  Main Dishes  30  40
# 29                     Mexican Baked Spaghetti Squash  Main Dishes  30  35
# 30          Risotto With Lemon And Sun Dried Tomatoes  Main Dishes  15  40
# 31             Red Cabbage, Cranberry, and Apple Slaw       Salads  15   5
# 32  Quinoa Salad with Grilled Scallions, Favas and...       Salads  15   5
# 33                     Mixed Greens with Smoked Gouda       Salads  15   5
# 34                               Crunchy Romaine Toss       Salads  15   5
# 35                                         Panzanella       Salads  15   5
# 36  Mediterranean Chopped Salad with Tomatoes, Pep...       Salads  15   5
# 37                                     Cucumber Salad       Salads  15   5
# 38        Green Beans with Roasted Tomatoes and Cumin  Side Dishes  10  20
# 39                     Elote, or Mexican Grilled Corn  Side Dishes   5  30
# 40                             Glazed Root Vegetables  Side Dishes  10  30
# 41                               Roasted New Potatoes  Side Dishes   5  40
# 42                       Best Ever Boston Baked Beans  Side Dishes  10  30
# 43                      Cilantro Serrano Mexican Rice  Side Dishes  10  20
# 44                           Grilled Fresh Artichokes  Side Dishes  20  45
# 45                               Pineapple Fried Rice  Side Dishes  10  20
#
#                                               4                5   6   7   \
# 0                                                 Appetizer Tongs   1   0
# 1                     12 '' Oval Ceramic Platter  Appetizer Tongs   1   0
# 2                     12 '' Oval Ceramic Platter  Appetizer Tongs   0   1
# 3                     12 '' Oval Ceramic Platter  Appetizer Tongs   0   1
# 4                     12 '' Oval Ceramic Platter  Appetizer Tongs   0   0
# 5                     12 '' Oval Ceramic Platter  Appetizer Tongs   1   0
# 6                     12 '' Oval Ceramic Platter  Appetizer Tongs   1   0
# 7   18" x 5" Rectangular Ceramic Serving Platter    Serving Tongs   1   0
# 8   18" x 5" Rectangular Ceramic Serving Platter    Serving Tongs   1   0
# 9   18" x 5" Rectangular Ceramic Serving Platter    Serving Tongs   1   0
# 10  18" x 5" Rectangular Ceramic Serving Platter    Serving Tongs   1   0
# 11                    12 '' Oval Ceramic Platter          Spatula   0   1
# 12                    12 '' Oval Ceramic Platter  Appetizer Tongs   0   0
# 13                    Porcelain Dinner Plate-10"          Spatula   1   0
# 14                    Porcelain Dinner Plate-10"          Spatula   1   0
# 15                    12 '' Oval Ceramic Platter  Appetizer Tongs   0   0
# 16                    12 '' Oval Ceramic Platter  Appetizer Tongs   0   0
# 17                    12 '' Oval Ceramic Platter  Appetizer Tongs   0   0
# 18                    12 '' Oval Ceramic Platter          Spatula   1   0
# 19                      Rectangular Chafing Dish    Serving Tongs   1   0
# 20                      Rectangular Chafing Dish    Serving Tongs   1   0
# 21                      Rectangular Chafing Dish    Serving Spoon   1   0
# 22                      Rectangular Chafing Dish    Serving Tongs   1   1
# 23                      Rectangular Chafing Dish    Serving Tongs   1   0
# 24                      Rectangular Chafing Dish    Serving Tongs   1   0
# 25                      Rectangular Chafing Dish          Spatula   1   1
# 26                      Rectangular Chafing Dish    Serving Spoon   1   0
# 27                      Rectangular Chafing Dish          Spatula   1   0
# 28                      Rectangular Chafing Dish    Serving Spoon   1   0
# 29                      Rectangular Chafing Dish    Serving Spoon   1   0
# 30                      Rectangular Chafing Dish    Serving Tongs   1   0
# 31                            Salad Serving Bowl    Serving Tongs   0   1
# 32                            Salad Serving Bowl    Serving Spoon   0   1
# 33                            Salad Serving Bowl    Serving Tongs   0   1
# 34                            Salad Serving Bowl    Serving Tongs   0   1
# 35                            Salad Serving Bowl    Serving Spoon   0   1
# 36                            Salad Serving Bowl    Serving Tongs   0   1
# 37                            Salad Serving Bowl    Serving Spoon   0   1
# 38                            Round Chafing Dish    Serving Tongs   1   0
# 39                            Round Chafing Dish    Serving Tongs   1   0
# 40                            Round Chafing Dish    Serving Spoon   1   0
# 41                            Round Chafing Dish    Serving Spoon   1   0
# 42                            Round Chafing Dish    Serving Spoon   1   0
# 43                            Round Chafing Dish    Serving Spoon   1   0
# 44                            Round Chafing Dish    Serving Tongs   1   0
# 45                            Round Chafing Dish    Serving Spoon   1   0
#
#        8                                             9      10         11
# 0    2.49                                          None    NaN       None
# 1    0.99                    12 '' Oval Ceramic Platter   2.42    Serving
# 2    1.49                    12 '' Oval Ceramic Platter   2.42    Serving
# 3    1.99                    12 '' Oval Ceramic Platter   2.42    Serving
# 4    2.49                    12 '' Oval Ceramic Platter   2.42    Serving
# 5    2.49                    12 '' Oval Ceramic Platter   2.42    Serving
# 6    1.99                    12 '' Oval Ceramic Platter   2.42    Serving
# 7    2.49  18" x 5" Rectangular Ceramic Serving Platter   4.85    Serving
# 8    2.99  18" x 5" Rectangular Ceramic Serving Platter   4.85    Serving
# 9    2.49  18" x 5" Rectangular Ceramic Serving Platter   4.85    Serving
# 10   3.49  18" x 5" Rectangular Ceramic Serving Platter   4.85    Serving
# 11  19.99                    12 '' Oval Ceramic Platter   2.42    Serving
# 12   2.49                    12 '' Oval Ceramic Platter   2.42    Serving
# 13  14.99                    Porcelain Dinner Plate-10"   1.50  Tableware
# 14  14.99                    Porcelain Dinner Plate-10"   1.50  Tableware
# 15   1.99                    12 '' Oval Ceramic Platter   2.42    Serving
# 16   2.99                    12 '' Oval Ceramic Platter   2.42    Serving
# 17   2.49                    12 '' Oval Ceramic Platter   2.42    Serving
# 18  24.99                    12 '' Oval Ceramic Platter   2.42    Serving
# 19  27.99                      Rectangular Chafing Dish  23.28    Serving
# 20  19.99                      Rectangular Chafing Dish  23.28    Serving
# 21  22.99                      Rectangular Chafing Dish  23.28    Serving
# 22  21.99                      Rectangular Chafing Dish  23.28    Serving
# 23  29.99                      Rectangular Chafing Dish  23.28    Serving
# 24  32.99                      Rectangular Chafing Dish  23.28    Serving
# 25  34.99                      Rectangular Chafing Dish  23.28    Serving
# 26  23.99                      Rectangular Chafing Dish  23.28    Serving
# 27  21.99                      Rectangular Chafing Dish  23.28    Serving
# 28  26.99                      Rectangular Chafing Dish  23.28    Serving
# 29  21.99                      Rectangular Chafing Dish  23.28    Serving
# 30  22.99                      Rectangular Chafing Dish  23.28    Serving
# 31   7.99                            Salad Serving Bowl   3.90    Serving
# 32   6.99                            Salad Serving Bowl   3.90    Serving
# 33   7.99                            Salad Serving Bowl   3.90    Serving
# 34   6.99                            Salad Serving Bowl   3.90    Serving
# 35   5.99                            Salad Serving Bowl   3.90    Serving
# 36   8.99                            Salad Serving Bowl   3.90    Serving
# 37   6.99                            Salad Serving Bowl   3.90    Serving
# 38   4.99                            Round Chafing Dish  17.20    Serving
# 39   4.99                            Round Chafing Dish  17.20    Serving
# 40   3.99                            Round Chafing Dish  17.20    Serving
# 41   3.99                            Round Chafing Dish  17.20    Serving
# 42   4.99                            Round Chafing Dish  17.20    Serving
# 43   3.99                            Round Chafing Dish  17.20    Serving
# 44   7.99                            Round Chafing Dish  17.20    Serving
# 45   4.99                            Round Chafing Dish  17.20    Serving

# %%
menu_items_list_json= list(zip(menu_item_details.keys(), list(menu_item_details)))

# %%
menu_items_list_json
# Out:
# [('name', 'Baked Chicken Wings with Thai Peanut Sauce'),
#  ('course', 'Appetizers'),
#  ('prep_time', 40),
#  ('cook_time', 50),
#  ('serving_container', "12 '' Oval Ceramic Platter"),
#  ('serving_utensil', 'Appetizer Tongs'),
#  ('oven', 1),
#  ('fridge', 0),
#  ('cost_per_item', 2.49)]

# %%
pd.DataFrame(ingredient_details)
# Out:
#                                             0           1   2   3   \
# 0   Baked Chicken Wings with Thai Peanut Sauce  Appetizers  40  50
# 1   Baked Chicken Wings with Thai Peanut Sauce  Appetizers  40  50
# 2   Baked Chicken Wings with Thai Peanut Sauce  Appetizers  40  50
# 3   Baked Chicken Wings with Thai Peanut Sauce  Appetizers  40  50
# 4   Baked Chicken Wings with Thai Peanut Sauce  Appetizers  40  50
# 5   Baked Chicken Wings with Thai Peanut Sauce  Appetizers  40  50
# 6   Baked Chicken Wings with Thai Peanut Sauce  Appetizers  40  50
# 7   Baked Chicken Wings with Thai Peanut Sauce  Appetizers  40  50
# 8   Baked Chicken Wings with Thai Peanut Sauce  Appetizers  40  50
# 9   Baked Chicken Wings with Thai Peanut Sauce  Appetizers  40  50
# 10  Baked Chicken Wings with Thai Peanut Sauce  Appetizers  40  50
# 11  Baked Chicken Wings with Thai Peanut Sauce  Appetizers  40  50
#
#                             4                5   6   7     8   \
# 0   12 '' Oval Ceramic Platter  Appetizer Tongs   1   0  2.49
# 1   12 '' Oval Ceramic Platter  Appetizer Tongs   1   0  2.49
# 2   12 '' Oval Ceramic Platter  Appetizer Tongs   1   0  2.49
# 3   12 '' Oval Ceramic Platter  Appetizer Tongs   1   0  2.49
# 4   12 '' Oval Ceramic Platter  Appetizer Tongs   1   0  2.49
# 5   12 '' Oval Ceramic Platter  Appetizer Tongs   1   0  2.49
# 6   12 '' Oval Ceramic Platter  Appetizer Tongs   1   0  2.49
# 7   12 '' Oval Ceramic Platter  Appetizer Tongs   1   0  2.49
# 8   12 '' Oval Ceramic Platter  Appetizer Tongs   1   0  2.49
# 9   12 '' Oval Ceramic Platter  Appetizer Tongs   1   0  2.49
# 10  12 '' Oval Ceramic Platter  Appetizer Tongs   1   0  2.49
# 11  12 '' Oval Ceramic Platter  Appetizer Tongs   1   0  2.49
#
#                                             9   \
# 0   Baked Chicken Wings with Thai Peanut Sauce
# 1   Baked Chicken Wings with Thai Peanut Sauce
# 2   Baked Chicken Wings with Thai Peanut Sauce
# 3   Baked Chicken Wings with Thai Peanut Sauce
# 4   Baked Chicken Wings with Thai Peanut Sauce
# 5   Baked Chicken Wings with Thai Peanut Sauce
# 6   Baked Chicken Wings with Thai Peanut Sauce
# 7   Baked Chicken Wings with Thai Peanut Sauce
# 8   Baked Chicken Wings with Thai Peanut Sauce
# 9   Baked Chicken Wings with Thai Peanut Sauce
# 10  Baked Chicken Wings with Thai Peanut Sauce
# 11  Baked Chicken Wings with Thai Peanut Sauce
#
#                                                    10   11  12
# 0           cloves garlic, peeled and roughly chopped  2.0  40
# 1                                       cooking spray  0.0  40
# 2                                    cup coconut milk  1.0  40
# 3                            cup smooth peanut butter  0.5  40
# 4   inch knob ginger, peeled and roughly chopped (...  1.0  40
# 5   lime wedges, chopped green onion, chopped cila...  0.0  40
# 6                                        lime, juiced  0.5  40
# 7   pounds chicken wings, skinned with tips remove...  5.0  40
# 8                             tablespoons brown sugar  2.0  40
# 9                              tablespoons fish sauce  2.0  40
# 10                         teaspoon red pepper flakes  0.5  40
# 11                                teaspoon sesame oil  1.0  40

# %%
ingredient_details[0].keys()
# Out:
# ['name',
#  'course',
#  'prep_time',
#  'cook_time',
#  'serving_container',
#  'serving_utensil',
#  'oven',
#  'fridge',
#  'cost_per_item',
#  'menu_item',
#  'menu_item_ingredient',
#  'quantity',
#  'production_amount']

# %%
production = ('production_amount', ingredient_details[0]['production_amount'])

# %%
items_quantities = sum([list(x)[1::-1] for x in ingredient_details], [])
labels = ingredient_details[0].keys()[1::-1] * len(ingredient_details)
labels = [labels[x] + '_' + str(x//2 + 1) for x in range(len(labels))]
production = [('production_amount', ingredient_details[0]['production_amount'])]
ingredients_list_json = production + list(zip(labels, items_quantities))

# %%
ingredients_list_json
# Out:
# [('production_amount', 5),
#  ('quantity_1', 1.0),
#  ('menu_item_ingredient_1',
#   '(10 ounce) package frozen chopped spinach, thawed and squeezed dry'),
#  ('quantity_2', 1.0),
#  ('menu_item_ingredient_2', '(15 ounce) container ricotta cheese'),
#  ('quantity_3', 1.0),
#  ('menu_item_ingredient_3', '(8 ounce) package manicotti shells'),
#  ('quantity_4', 1.0),
#  ('menu_item_ingredient_4', '1/2 cups shredded mozzarella cheese, divided'),
#  ('quantity_5', 0.5),
#  ('menu_item_ingredient_5', 'cup grated Parmesan cheese, divided'),
#  ('quantity_6', 0.5),
#  ('menu_item_ingredient_6', 'cup minced onion'),
#  ('quantity_7', 6.0),
#  ('menu_item_ingredient_7', 'cups ClassicoÃ‚Â® Tomato and Basil Sauce'),
#  ('quantity_8', 1.5),
#  ('menu_item_ingredient_8', 'cups water'),
#  ('quantity_9', 1.0),
#  ('menu_item_ingredient_9', 'egg'),
#  ('quantity_10', 0.25),
#  ('menu_item_ingredient_10', 'teaspoon garlic powder'),
#  ('quantity_11', 0.5),
#  ('menu_item_ingredient_11', 'teaspoon pepper'),
#  ('quantity_12', 2.0),
#  ('menu_item_ingredient_12', 'teaspoons minced fresh parsley')]

# %%
full_list_json = menu_items_list_json + ingredients_list_json
dict(full_list_json)
# Out:
# {'name': 'Beet-Pickled Quail Eggs',
#  'course': 'Appetizers',
#  'prep_time': 20,
#  'cook_time': 10,
#  'serving_container': "12 '' Oval Ceramic Platter",
#  'serving_utensil': 'Appetizer Tongs',
#  'oven': 0,
#  'fridge': 1,
#  'cost_per_item': 1.99,
#  'menu_item_ingredient_1': 0.0,
#  'quantity_1': 'Hot sauce, celery leaves, and flaky sea salt, for serving',
#  'menu_item_ingredient_2': 0.5,
#  'quantity_2': 'cup sugar',
#  'menu_item_ingredient_3': 1.0,
#  'quantity_3': 'cup white balsamic vinegar',
#  'menu_item_ingredient_4': 1.0,
#  'quantity_4': 'dried bay leaf',
#  'menu_item_ingredient_5': 24.0,
#  'quantity_5': 'quail eggs (available at dartagnan.com)',
#  'menu_item_ingredient_6': 1.0,
#  'quantity_6': 'small red beet, peeled and coarsely grated',
#  'menu_item_ingredient_7': 1.0,
#  'quantity_7': 'teaspoon coarse salt',
#  'menu_item_ingredient_8': 1.0,
#  'quantity_8': 'teaspoon juniper berries'}

# %%
items_quantities = sum([list(x)[2:0] for x in ingredient_details], [])

# %%
[list(x)[2:0:-1] for x in ingredient_details]
# Out:
# [[8, 0.0],
#  [8, 0.5],
#  [8, 1.0],
#  [8, 1.0],
#  [8, 24.0],
#  [8, 1.0],
#  [8, 1.0],
#  [8, 1.0]]

# %%
mydict = {'name': 'Budweiser 12 Pack Bottles', 'cost_per_item': 26.24, 'category': 'Beer', 'serving_container': 'Beer Pilsner Glass'}

# %%
for x in mydict.items():
    print(x[0] + ' = "' + str(x[1]) + '"')
# Out:
# name = "Budweiser 12 Pack Bottles"
# cost_per_item = "26.24"
# category = "Beer"
# serving_container = "Beer Pilsner Glass"

# %%
valueslist = [x[0] + ' = "' + str(x[1]) + '"' if type(x[1]) == str else x[0] + ' = ' + str(x[1]) for x in mydict.items()]

# %%
', '.join(valueslist)
# Out:
# 'name = "Budweiser 12 Pack Bottles", cost_per_item = 26.24, category = "Beer", serving_container = "Beer Pilsner Glass"'

# %%
pd.DataFrame(conn.execute("UPDATE bar_items SET ").fetchall())
# Out:
#                                       0      1            2  \
# 0                        Coke 2L Bottle   5.48  Soft Drinks
# 1                   Diet Coke 2L Bottle   5.48  Soft Drinks
# 2                      Sprite 2L Bottle   5.48  Soft Drinks
# 3                  Dr. Pepper 2L Bottle   5.28  Soft Drinks
# 4                       Fanta 2L Bottle   3.76  Soft Drinks
# 5                Modelo 12 Pack Bottles  32.84         Beer
# 6             Budweiser 12 Pack Bottles  26.24         Beer
# 7             Bud Light 12 Pack Bottles  26.24         Beer
# 8              Heineken 12 Pack Bottles  32.88         Beer
# 9             Lagunitas 12 Pack Bottles  33.68         Beer
# 10        Sierra Nevada 12 Pack Bottles  39.46         Beer
# 11    Barefoot Chardonnay 750 mL Bottle  11.92         Wine
# 12      Apothic Red Blend 750 mL Bottle  18.24         Wine
# 13    La Crema Pinor Noir 750 mL Bottle  45.96         Wine
# 14   Yellow Tail Reisling 750 mL Bottle  19.74         Wine
# 15       Kirkland Chianti 750 mL Bottle  17.98         Wine
# 16   Cupcake Pinot Grigio 750 mL Bottle  17.66         Wine
# 17    Bollinger Champagne 750 mL Bottle  65.80         Wine
# 18  Jack Daniel's Whiskey 750 mL Bottle  35.96       Liquor
# 19         Smirnoff Vodka 750 mL Bottle  39.74       Liquor
# 20            Bacardi Rum 750 mL Bottle  39.96       Liquor
# 21         Patron Tequila 750 mL Bottle  70.24       Liquor
# 22          Tanquerey Gin 750 mL Bottle  47.68       Liquor
#
#                       3
# 0     Plastic Cups 12oz
# 1     Plastic Cups 12oz
# 2     Plastic Cups 12oz
# 3     Plastic Cups 12oz
# 4     Plastic Cups 12oz
# 5    Beer Pilsner Glass
# 6    Beer Pilsner Glass
# 7    Beer Pilsner Glass
# 8    Beer Pilsner Glass
# 9    Beer Pilsner Glass
# 10   Beer Pilsner Glass
# 11      White Wine-11oz
# 12       Red Wine-12oz.
# 13       Red Wine-12oz.
# 14      White Wine-11oz
# 15       Red Wine-12oz.
# 16      White Wine-11oz
# 17      Champagne Flute
# 18  Old Fashioned Glass
# 19  Old Fashioned Glass
# 20  Old Fashioned Glass
# 21  Old Fashioned Glass
# 22  Old Fashioned Glass

# %%
conn.close()

# %%
mydict = {'name': 'Grilled Fresh Artichokes', 'course': 'Side Dishes', 'prep_time': '20', 'cook_time': '45', 'serving_container': 'Round Chafing Dish', 'serving_utensil': 'Serving Tongs', 'oven': '1', 'fridge': '0', 'cost_per_item': '7.99', 'production_amount': '10', 'quantity_1': '4', 'menu_item_ingredient_1': 'fresh artichokes (about 3/4 lb. each)', 'quantity_2': '5', 'menu_item_ingredient_2': 'fresh parsley sprigs', 'quantity_3': '3', 'menu_item_ingredient_3': 'garlic cloves', 'quantity_4': '0', 'menu_item_ingredient_4': 'garnish: fresh flat-leaf parsley sprigs', 'quantity_5': '1', 'menu_item_ingredient_5': 'lemon, thinly sliced', 'quantity_6': '0', 'menu_item_ingredient_6': 'salt and pepper', 'quantity_7': '3', 'menu_item_ingredient_7': 'tablespoons olive oil', 'quantity_8': '2', 'menu_item_ingredient_8': 'teaspoons salt'}

# %%
mydict
# Out:
# {'name': 'Grilled Fresh Artichokes',
#  'course': 'Side Dishes',
#  'prep_time': '20',
#  'cook_time': '45',
#  'serving_container': 'Round Chafing Dish',
#  'serving_utensil': 'Serving Tongs',
#  'oven': '1',
#  'fridge': '0',
#  'cost_per_item': '7.99',
#  'production_amount': '10',
#  'quantity_1': '4',
#  'menu_item_ingredient_1': 'fresh artichokes (about 3/4 lb. each)',
#  'quantity_2': '5',
#  'menu_item_ingredient_2': 'fresh parsley sprigs',
#  'quantity_3': '3',
#  'menu_item_ingredient_3': 'garlic cloves',
#  'quantity_4': '0',
#  'menu_item_ingredient_4': 'garnish: fresh flat-leaf parsley sprigs',
#  'quantity_5': '1',
#  'menu_item_ingredient_5': 'lemon, thinly sliced',
#  'quantity_6': '0',
#  'menu_item_ingredient_6': 'salt and pepper',
#  'quantity_7': '3',
#  'menu_item_ingredient_7': 'tablespoons olive oil',
#  'quantity_8': '2',
#  'menu_item_ingredient_8': 'teaspoons salt'}

# %%
menu_items_updates = [updates[0] + ' = "' + str(updates[1]) + '"' for updates in list(mydict.items())[0:9]]

# %%
menu_items_values_clause = ', '.join(menu_items_updates)

# %%
menu_items_values_clause
# Out:
# 'name = "Grilled Fresh Artichokes", course = "Side Dishes", prep_time = "20", cook_time = "45", serving_container = "Round Chafing Dish", serving_utensil = "Serving Tongs", oven = "1", fridge = "0", cost_per_item = "7.99"'

# %%
quantities = ['"' + str(update[1]) + '"' for update in list(mydict.items())[10::2]]
ingredients = ['"' + str(update[1]) + '"' for update in list(mydict.items())[11::2]]
production = ['"' + mydict['production_amount'] + '"' for x in range(len(quantities))]
menu_item = [mydict['name'] for x in range(len(quantities))]

# %%
menu_item
# Out:
# ['Grilled Fresh Artichokes',
#  'Grilled Fresh Artichokes',
#  'Grilled Fresh Artichokes',
#  'Grilled Fresh Artichokes',
#  'Grilled Fresh Artichokes',
#  'Grilled Fresh Artichokes',
#  'Grilled Fresh Artichokes',
#  'Grilled Fresh Artichokes']

# %%
update_query = 'INSERT INTO menu_item_ingredients (menu_item, quantity, menu_item_ingredien, production_amount) VALUES '  + ''.join(["(" + menu_item[x] + ', ' + quantities[x] + ', ' + ingredients[x] + ', ' + production[x] + ")," for x in range(len(quantities))])[:-1]

# %%
update_query
# Out:
# 'INSERT INTO menu_item_ingredients (menu_item, quantity, menu_item_ingredien, production_amount) VALUES (Grilled Fresh Artichokes, "4", "fresh artichokes (about 3/4 lb. each)", "10"),(Grilled Fresh Artichokes, "5", "fresh parsley sprigs", "10"),(Grilled Fresh Artichokes, "3", "garlic cloves", "10"),(Grilled Fresh Artichokes, "0", "garnish: fresh flat-leaf parsley sprigs", "10"),(Grilled Fresh Artichokes, "1", "lemon, thinly sliced", "10"),(Grilled Fresh Artichokes, "0", "salt and pepper", "10"),(Grilled Fresh Artichokes, "3", "tablespoons olive oil", "10"),(Grilled Fresh Artichokes, "2", "teaspoons salt", "10")'

# %%
delete_query = f'DELETE FROM menu_item_ingredients WHERE menu_item = {mydict['name']}'

# %%
delete_query
# Out:
# 'DELETE FROM menu_item_ingredients WHERE menu_item = Grilled Fresh Artichokes'

# %%
row = conn.execute("SELECT * FROM menu_items LEFT JOIN menu_item_ingredients ON menu_items.name = menu_item_ingredients.menu_item").fetchall()

# %%
dict(zip(row.keys(), ['' for c in range(len(row.keys()))]))
# Out:
# {'name': '',
#  'course': '',
#  'prep_time': '',
#  'cook_time': '',
#  'serving_container': '',
#  'serving_utensil': '',
#  'oven': '',
#  'fridge': '',
#  'cost_per_item': '',
#  'menu_item': '',
#  'menu_item_ingredient': '',
#  'quantity': '',
#  'production_amount': ''}

# %%
my_string = ['string', 'another_string']

# %%
second_string = my_string.copy()

# %%
second_string[0] = 'blah'

# %%
for (x, y) in enumerate(my_string):
    print(x,y)
# Out:
# 0 string
# 1 another_string

# %%
my_string[:0] + ['third_string'] + my_string[0:]
# Out:
# ['third_string', 'string', 'another_string']

# %%
my_string.pop(1)
# Out:
# 'another_string'

# %%
ingredients = ['"Salt and freshly ground pepper, to taste"', '"Tbs. finely chopped fresh rosemary or 1 1Ã¢Â\x81â€ž2 tsp. dried"', '"cup extra-virgin olive oil-"', '"garlic cloves, minced"', '"lb. small to medium new potatoes, scrubbed"']

# %%
for (x, ingredient) in enumerate(ingredients.copy()):
    if ingredient[-2:] == '+"':
        ingredients = ingredients[:x+1] + ['"New ingredient"',] + ingredients[x+1:]
        quantities = quantities[:x+1] + ['0'] + quantities[x+1:]
        production = production + production[:1]
        menu_item = menu_item + menu_item[:1]
    elif ingredient[-2:] == '-"':
        ingredients = ingredient[:x] + ingredients[1+x:]
        quantities = quantities[:x] + quantities[1+x:]
        production = production[:-1]
        menu_item = menu_item[:-1]
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[467], line 8
#       6     menu_item = menu_item + menu_item[:1]
#       7 elif ingredient[-2:] == '-"':
# ----> 8     ingredients = ingredient[:x] + ingredients[1+x:]
#       9     quantities = quantities[:x] + quantities[1+x:]
#      10     production = production[:-1]
#
# TypeError: can only concatenate str (not "list") to str

# %%
ingredients = conn.execute("SELECT * FROM menu_item_ingredients").fetchall()

# %%
pd.DataFrame(ingredients)
# Out:
#                                               0  \
# 0                            Bruschetta Caprese
# 1                            Bruschetta Caprese
# 2                            Bruschetta Caprese
# 3                            Bruschetta Caprese
# 4                            Bruschetta Caprese
# ..                                          ...
# 506  Baked Chicken Wings with Thai Peanut Sauce
# 507  Baked Chicken Wings with Thai Peanut Sauce
# 508  Baked Chicken Wings with Thai Peanut Sauce
# 509  Baked Chicken Wings with Thai Peanut Sauce
# 510  Baked Chicken Wings with Thai Peanut Sauce
#
#                                                      1    2   3
# 0    to 12 Italian bread slices (depends on the siz...  6.0   6
# 1                           cup Extra Virgin Olive Oli  1.0   6
# 2                               tablespoon dry oregano  1.0   6
# 3                                                 salt  0.0   6
# 4                                         garlic clove  1.0   6
# ..                                                 ...  ...  ..
# 506                                       lime, juiced  0.5  40
# 507  pounds chicken wings, skinned with tips remove...  6.0  40
# 508                            tablespoons brown sugar  2.0  40
# 509                             tablespoons fish sauce  2.0  40
# 510                         teaspoon red pepper flakes  0.5  40
#
# [511 rows x 4 columns]
